# %%
import pandas as pandas
import seaborn as sns

# %%
# Base de dados do MovieLens (https://files.grouplens.org/datasets/movielens/ml-25m.zip)
# Carregando notas (ratings.csv)
data_frame = pandas.read_csv('./dados/ratings.csv')
data_frame.columns = ['user_id', 'movie_id', 'rating', 'timestamp']
print("Average:", data_frame["rating"].mean())
# Out:
# Average: 3.501556983616962

# %%
# Contar quantas vezes cada nota foi dada
print(data_frame["rating"].value_counts())

# Exibir quais notas foram dadas
print("\nNotas dadas:", data_frame["rating"].unique())
# Out:
# rating
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64
#
# Notas dadas: [4.  5.  3.  2.  1.  4.5 3.5 2.5 0.5 1.5]

# %%
# Criação de Histograma das notas dadas pelos usuários
data_frame["rating"].plot(kind='hist', title='Rating Distribution', ylabel='Users', xlabel='Rating')
# Out:
# <Axes: title={'center': 'Rating Distribution'}, xlabel='Rating', ylabel='Users'>

# %%
# Entendimento da diferença enrte média e mediana
median = data_frame["rating"].median()
average = data_frame["rating"].mean()

print(f"Mediana: {median}\n{f'Média: {average}'}")
# Out:
# Mediana: 3.5
# Média: 3.501556983616962

# %%
data_frame["rating"].describe()
# Count: quantidade de notas
# Mean: média das notas
# Std: desvio padrão
# Min: menor nota
# 25%: 25% das notas estão abaixo desse valor
# 50%: 50% das notas estão abaixo desse valor (mediana)
# 75%: 75% das notas estão abaixo desse valor
# Max: maior nota
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
sns.boxplot(data_frame["rating"])
# Boxplot é um gráfico que apresenta a distribuição de dados de forma mais visual
# A linha no meio é a mediana
# As caixas azuis representas 50% dos dados (25% por cada caixa)
# Out:
# <Axes: ylabel='rating'>
